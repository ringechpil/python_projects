# %% [markdown]
# # Blackjack with split

# %% [markdown]
# ## Game Play
# To play a hand of Blackjack the following steps must be followed:
# 1. Create a deck of 52 cards
# 2. Shuffle the deck
# 3. Ask the Player for their bet
# 4. Make sure that the Player's bet does not exceed their available chips
# 5. Deal two cards to the Dealer and two cards to the Player
# 6. Show only one of the Dealer's cards, the other remains hidden
# 7. Show both of the Player's cards
# 8. Ask the Player if they wish to Hit, and take another card
# 9. If the Player's hand doesn't Bust (go over 21), ask if they'd like to Hit again.
# 10. If a Player Stands, play the Dealer's hand. The dealer will always Hit until the Dealer's value meets or exceeds 17
# 11. Determine the winner and adjust the Player's chips accordingly
# 12. Ask the Player if they'd like to play again

# %% [markdown]
# **Import the cards**

# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

# %% [markdown]
# **Create a Card Class**

# %%
class Card:
    
    def __init__(self,rank,suit):
        self.suit = suit
        self.rank = rank
    
    def __str__(self):
        return '{} of {}'.format(self.rank,self.suit)

# %% [markdown]
# **Create a Deck Class**

# %%
class Deck:
    
    def __init__(self):
        self.deck = [Card(rank,suit) for rank in ranks for suit in suits]
    
    def __str__(self):
         return str(['{} of {}'.format(Card.rank,Card.suit) for Card in self.deck])

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        return self.deck.pop(0)

# %% [markdown]
# **Create a Hand Class**

# %%
class Hand:
    def __init__(self):
        self.cards = []  
        self.value = 0   
        self.aces = 0    
    
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.rank]
        
        if (card.rank == 'Ace'):
            self.aces += 1
        
    def adjust_for_ace(self):
        self.value -= 10*self.aces

# %% [markdown]
# **Create a Chips Class**

# %%
class Chips:
    
    def __init__(self):
        self.total = 100  
        self.bet = 0
    
    def __str__(self):
        return 'You currently have {} dollars.'.format(self.total)
        
    def win_bet(self):
        self.total += 2*self.bet
    
    def lose_bet(self):
        self.total -= self.bet

# %% [markdown]
# **Write a function for taking bets**

# %%
def take_bet(chips):
    
    while True:
        try:
            bet = int(input('Place your bet.'))
            if (bet > chips.total):
                print('Can\'t do.')
                print('You can bet {} or less.'.format(chips))
            else:
                chips.bet = bet
                break
        
        except:
            print('Only integers allowed, dude.')

# %% [markdown]
# **Write a function for taking hits**

# %%
def hit(deck,hand):
    
    card = deck.deal()
    hand.add_card(card)
    
    if (hand.value > 21):
        hand.adjust_for_ace()
        hand.aces = 0

# %% [markdown]
# **Write a function prompting the Player to Hit or Stand**

# %%
def hit_or_stand(deck,hand):
    global playing  
    
    while True:
        
        tok = input('Hit or Stand (h\s)?').lower()
        if (tok == 'h'):
            hit(deck,hand)
            break
        elif (tok == 's'):
            playing = False
            break
        else:
            print('Input not understood')

# %% [markdown]
# **Write functions to display cards**

# %%
def show_some(player,dealer):
    
    print("Dealer's hand:")
    rev_card = dealer.cards[1]
    print(rev_card)
    print("Value of the revealed card {}".format(values[rev_card.rank]))
    
    print('-----------------------------')
    
    print('Your hand:')
    for card in player.cards:
        print(card)
    print('------------------')
    print('Your hand value: {}'.format(player.value))

    
def show_all(player,dealer):
    
    print("Dealer's hand:")
    for card in dealer.cards:
        print(card)
    print('------------------')
    print("Dealer's hand value: {}".format(dealer.value))
    
    print('-----------------------------')
    
    print('Your hand:')
    for card in player.cards:
        print(card)
    print('------------------')
    print('Your hand value: {}'.format(player.value))

# %% [markdown]
# **Write functions to handle end of game scenarios**

# %%
def player_busts(chips):
    print("You busted, you bastard!")
    chips.lose_bet()

def player_wins(chips):
    print('Congrats!')
    chips.win_bet()

def dealer_busts(chips):
    print('Diler got busted.')
    chips.win_bet()
    
def dealer_wins(chips):
    print('Fuck it, he\'s stronger...')
    chips.lose_bet()
    
def push():
    print('Noting happend. A tie.')

# %% [markdown]
# ### And now on to the game!!

# %%
def reg_game():
    
    global playing
    playing = True
    bust = False
    
    while playing:  # recall this variable from our hit_or_stand function

        # Prompt for Player to Hit or Stand
        hit_or_stand(D,player)


        # Show cards (but keep one dealer card hidden)
        show_some(player, dealer)
        print('::::::::::::::::::::::::::::::')


        # If player's hand exceeds 21, run player_busts() and break out of loop
        if (player.value > 21):
            player_busts(money)
            bust = True
            break
        elif (player.value == 21):
            break

        print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^')

    # If Player hasn't busted, play Dealer's hand until Dealer reaches 17
    if not bust:
        while (dealer.value < 17):
            hit(D,dealer)

        # Show all cards
        show_all(player,dealer)
        print('::::::::::::::::::::::::::::::')

        # Run different winning scenarios
        if (dealer.value > 21):
            dealer_busts(money)
        elif (dealer.value > player.value):
            dealer_wins(money)
        elif (player.value > dealer.value):
            player_wins(money)
        elif (player.value == dealer.value):
            push()

# %%
def split_game():
    
    global playing
    
    hand1 = Hand()
    hand2 = Hand()
    
    hand1.add_card(player.cards.pop())
    hand2.add_card(player.cards.pop())
    

    print("FIRST HAND")
    
    playing = True
    bust1 = False
    hit(D,hand1)
    show_some(hand1,dealer)
    
    while playing:  # recall this variable from our hit_or_stand function

        # Prompt for Player to Hit or Stand
        hit_or_stand(D,hand1)


        # Show cards (but keep one dealer card hidden)
        show_some(hand1, dealer)
        print('::::::::::::::::::::::::::::::')


        # If player's hand exceeds 21, run player_busts() and break out of loop
        if (hand1.value > 21):
            print('First hand busted!')
            bust1 = True
            player_busts(money)
            break
        elif (hand1.value == 21):
            print('First hand won!')
            player_busts(money)
            break

    print('~~~~~~~~~~~~~')
    print('SECOND HAND')
    
    playing = True
    bust2 = False
    hit(D,hand2)
    show_some(hand2,dealer)
    
    while playing:  # recall this variable from our hit_or_stand function

        # Prompt for Player to Hit or Stand
        hit_or_stand(D,hand2)


        # Show cards (but keep one dealer card hidden)
        show_some(hand2, dealer)
        print('::::::::::::::::::::::::::::::')


        # If player's hand exceeds 21, run player_busts() and break out of loop
        if (hand2.value > 21):
            print('Second hand busted!')
            bust2 = True
            break
        elif (hand2.value == 21):
            print('Second hand won')
            break
            
    
    if not bust1 or not bust2:
        
        while (dealer.value <= 17):
            hit(D,dealer)

        if not bust1:
            show_all(hand1,dealer)
            print('::::::::::::::::::::::::::::::')

            # Run different winning scenarios
            if (dealer.value > 21):
                dealer_busts(money)
            elif (dealer.value > hand1.value):
                dealer_wins(money)
            elif (hand1.value > dealer.value):
                player_wins(money)
            elif (hand1.value == dealer.value):
                push()
                
        
        if not bust2:
            show_all(hand2,dealer)
            print('::::::::::::::::::::::::::::::')

            # Run different winning scenarios
            if (dealer.value > 21):
                dealer_busts(money)
            elif (dealer.value > hand2.value):
                dealer_wins(money)
            elif (hand2.value > dealer.value):
                player_wins(money)
            elif (hand2.value == dealer.value):
                push()

# %%
igra = True
money = Chips()
while igra:
    # Print an opening statement
    print("Goooooo")
    print('................')
    
    
    # Create & shuffle the deck, deal two cards to each player
    D = Deck()
    D.shuffle()
    
    player = Hand()
    dealer = Hand()
    
    hit(D,player)
    hit(D,dealer)
    hit(D,player)
    hit(D,dealer)

    
    
    # Set up the Player's chips
    print(money)
    
    
    # Prompt the Player for their bet
    take_bet(money)
    print('~~~~~~~~~~~~~~~')

    
    # Show cards (but keep one dealer card hidden)
    show_some(player,dealer)
    print('::::::::::::::::::::::::::::::')
    
    val1 = player.cards[0].rank
    val2 = player.cards[1].rank
    
    if (val1 == val2) and (2*money.bet <= money.total):
        while True:
            splitaz = input('Split (yes or no)?').lower()
            if (splitaz == 'yes'):
                print('splitague')
                print('~~~~~~~~~~~~`')
                split_game()
                break
            elif (splitaz == 'no'):
                reg_game()
                break
            else:
                print('Input not understood.')
    
    else:
        reg_game()
    
    
    # Inform Player of their chips total 
    print('You have currently {} dollars'.format(money.total))

    # Ask to play again
    while True:
        if (money.total == 0):
            print('Busted!')
            igra = False
            break
        ponovo_ponovo_ponovo = input('One more (yes ili no)?').lower()
        if (ponovo_ponovo_ponovo == 'yes'):
            break
        elif (ponovo_ponovo_ponovo == 'no'):
            print('GAME OVER')
            igra = False
            break
        else:
            print('Input not understood.')
# Out:
# Goooooo
# ................
# You currently have 100 dollars.
# Place your bet.75
# ~~~~~~~~~~~~~~~
# Dealer's hand:
# Six of Spades
# Value of the revealed card 6
# -----------------------------
# Your hand:
# Queen of Hearts
# Two of Clubs
# ------------------
# Your hand value: 12
# ::::::::::::::::::::::::::::::
# Hit or Stand (h\s)?h
# Dealer's hand:
# Six of Spades
# Value of the revealed card 6
# -----------------------------
# Your hand:
# Queen of Hearts
# Two of Clubs
# Ten of Clubs
# ------------------
# Your hand value: 22
# ::::::::::::::::::::::::::::::
# You busted, you bastard!
# You have currently 25 dollars
# One more (yes ili no)?yes
# Goooooo
# ................
# You currently have 25 dollars.
# Place your bet.10
# ~~~~~~~~~~~~~~~
# Dealer's hand:
# King of Hearts
# Value of the revealed card 10
# -----------------------------
# Your hand:
# Two of Spades
# Two of Clubs
# ------------------
# Your hand value: 4
# ::::::::::::::::::::::::::::::
# Split (yes or no)?y
# Input not understood.
# Split (yes or no)?yes
# splitague
# ~~~~~~~~~~~~`
# FIRST HAND
# Dealer's hand:
# King of Hearts
# Value of the revealed card 10
# -----------------------------
# Your hand:
# Two of Clubs
# Five of Diamonds
# ------------------
# Your hand value: 7
# Hit or Stand (h\s)?h
# Dealer's hand:
# King of Hearts
# Value of the revealed card 10
# -----------------------------
# Your hand:
# Two of Clubs
# Five of Diamonds
# King of Clubs
# ------------------
# Your hand value: 17
# ::::::::::::::::::::::::::::::
# Hit or Stand (h\s)?s
# Dealer's hand:
# King of Hearts
# Value of the revealed card 10
# -----------------------------
# Your hand:
# Two of Clubs
# Five of Diamonds
# King of Clubs
# ------------------
# Your hand value: 17
# ::::::::::::::::::::::::::::::
# ~~~~~~~~~~~~~
# SECOND HAND
# Dealer's hand:
# King of Hearts
# Value of the revealed card 10
# -----------------------------
# Your hand:
# Two of Spades
# Seven of Diamonds
# ------------------
# Your hand value: 9
# Hit or Stand (h\s)?h
# Dealer's hand:
# King of Hearts
# Value of the revealed card 10
# -----------------------------
# Your hand:
# Two of Spades
# Seven of Diamonds
# Three of Hearts
# ------------------
# Your hand value: 12
# ::::::::::::::::::::::::::::::
# Hit or Stand (h\s)?h
# Dealer's hand:
# King of Hearts
# Value of the revealed card 10
# -----------------------------
# Your hand:
# Two of Spades
# Seven of Diamonds
# Three of Hearts
# Ten of Hearts
# ------------------
# Your hand value: 22
# ::::::::::::::::::::::::::::::
# Second hand busted!
# Dealer's hand:
# Two of Hearts
# King of Hearts
# Five of Hearts
# Eight of Clubs
# ------------------
# Dealer's hand value: 25
# -----------------------------
# Your hand:
# Two of Clubs
# Five of Diamonds
# King of Clubs
# ------------------
# Your hand value: 17
# ::::::::::::::::::::::::::::::
# Diler got busted.
# You have currently 45 dollars
# One more (yes ili no)?no
# GAME OVER
